# %% [markdown]
# # Exp-6: Compare the Performance of the Classification model using various Regularization Techniques.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets.mnist import load_data
import tensorflow.keras.regularizers as regularizers

# %%
(X_train, y_train), (X_test, y_test) = load_data()
X_train, X_test = X_train / 255., X_test / 255.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
def modelFactory(l1=False, l2=False, dropout=False):
  extra_prem = {}
  if l1:
    regularizers.L1(l1=.01)
    extra_prem['kernel_regularizer'] = 'l1'
  elif l2:
    regularizers.L2(l2=.01)
    extra_prem['kernel_regularizer'] = 'l2'
  model = Sequential([
      Flatten(input_shape=(28, 28)),
      Dense(128, activation='relu', **extra_prem),
      Dense(32, activation='relu', **extra_prem),
  ])
  if dropout:
    model.add(Dropout(.2))
  model.add(Dense(10, activation='softmax', **extra_prem))
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# ### L1

# %%
model_l1 = modelFactory(l1=True)
model_l1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 13s 3ms/step - loss: 2.8923 - accuracy: 0.7067 - val_loss: 1.7441 - val_accuracy: 0.7989
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.6602 - accuracy: 0.8065 - val_loss: 1.5428 - val_accuracy: 0.8317
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5378 - accuracy: 0.8297 - val_loss: 1.4895 - val_accuracy: 0.8410
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.4856 - accuracy: 0.8407 - val_loss: 1.4377 - val_accuracy: 0.8520
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4462 - accuracy: 0.8472 - val_loss: 1.4174 - val_accuracy: 0.8495

# %%
loss, acc = model_l1.evaluate(X_test, y_test)
acc
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4174 - accuracy: 0.8495
# 0.8495000004768372

# %% [markdown]
# ## L2

# %%
model_l2 = modelFactory(l2=True)
model_l2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 1.0205 - accuracy: 0.8843 - val_loss: 0.7966 - val_accuracy: 0.9152
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.8149 - accuracy: 0.9040 - val_loss: 0.7853 - val_accuracy: 0.9098
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7986 - accuracy: 0.9067 - val_loss: 0.7590 - val_accuracy: 0.9142
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.7877 - accuracy: 0.9094 - val_loss: 0.7681 - val_accuracy: 0.9105
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7823 - accuracy: 0.9086 - val_loss: 0.7706 - val_accuracy: 0.9100

# %%
loss, acc = model_l2.evaluate(X_test, y_test)
acc
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7706 - accuracy: 0.9100
# 0.9100000262260437

# %% [markdown]
# ## Dropout

# %%
model_dropout = modelFactory(dropout=True)
model_dropout.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.3236 - accuracy: 0.9050 - val_loss: 0.1599 - val_accuracy: 0.9511
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1427 - accuracy: 0.9581 - val_loss: 0.1016 - val_accuracy: 0.9689
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1077 - accuracy: 0.9683 - val_loss: 0.0944 - val_accuracy: 0.9705
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0830 - accuracy: 0.9754 - val_loss: 0.0870 - val_accuracy: 0.9726
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0678 - accuracy: 0.9788 - val_loss: 0.0801 - val_accuracy: 0.9784

# %%
loss, acc = model_dropout.evaluate(X_test, y_test)
acc
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0801 - accuracy: 0.9784
# 0.9783999919891357

# %% [markdown]
# ## Early Stopping

# %%
model_early = modelFactory()
model_early.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, callbacks=[EarlyStopping(monitor='accuracy', patience=2)])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2526 - accuracy: 0.9256 - val_loss: 0.1348 - val_accuracy: 0.9586
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1108 - accuracy: 0.9664 - val_loss: 0.1090 - val_accuracy: 0.9647
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0758 - accuracy: 0.9760 - val_loss: 0.0872 - val_accuracy: 0.9737
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0588 - accuracy: 0.9817 - val_loss: 0.0797 - val_accuracy: 0.9764
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0457 - accuracy: 0.9860 - val_loss: 0.0865 - val_accuracy: 0.9743
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.0861 - val_accuracy: 0.9760
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0311 - accuracy: 0.9901 - val_loss: 0.1005 - val_accuracy: 0.9710
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.1042 - val_accuracy: 0.9727
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0223 - accuracy: 0.9923 - val_loss: 0.0861 - val_accuracy: 0.9785
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.1146 - val_accuracy: 0.9735

# %%
loss, acc = model_early.evaluate(X_test, y_test)
acc
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1146 - accuracy: 0.9735
# 0.9735000133514404
