# %% [markdown]
# # Exp-2: Understanding of Deep learning Packages Basics: Tensorflow, Keras, Theano and PyTorch

# %% [markdown]
# ## Tensorflow and Keras

# %%
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras import Sequential

# %%
(X_train, y_train), (X_test, y_test) = load_data()
X_train, X_test = X_train / 255., X_test / 255.

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation="relu"),
    Dropout(.2),
    Dense(32, activation="relu"),
    Dropout(.2),
    Dense(10, activation="softmax"),
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 4ms/step - loss: 0.3848 - accuracy: 0.8860
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1830 - accuracy: 0.9462
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1478 - accuracy: 0.9563
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1220 - accuracy: 0.9635
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1062 - accuracy: 0.9690

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuray:", acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0886 - accuracy: 0.9745
# Test Accuray: 0.9745000004768372

# %% [markdown]
# ## PyTorch

# %%
import torch

# %%
t1 = torch.tensor([1, 2, 3])
t2 = torch.tensor([[1, 2, 3], [4, 5, 6]])

# %%
t1, t2
# Out:
# (tensor([1, 2, 3]),
#  tensor([[1, 2, 3],
#          [4, 5, 6]]))

# %%
t1.shape, t2.shape
# Out:
# (torch.Size([3]), torch.Size([2, 3]))

# %%
print("Ranks")
len(t1.shape), len(t2.shape)
# Out:
# Ranks
# (1, 2)

# %% [markdown]
# ## Theano

# %%
import numpy as np
import theano
import theano.tensor as T


x = T.dscalar('x')
y = T.dscalar('y')
z = x + y


addition = theano.function([x, y], z)

result = addition(2.5, 3.7)
print("Result:", result)
